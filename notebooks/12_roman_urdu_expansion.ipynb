# %%
# Cell 1 — Imports
import numpy as np
import pandas as pd
from collections import defaultdict
import re
import warnings
warnings.filterwarnings('ignore')

print("✅ Libraries loaded!")
# Out:
# ✅ Libraries loaded!

# %%
# Cell 2 — Existing Dictionary (30 words)
roman_to_urdu_base = {
    "cricket": "کرکٹ", "match": "میچ", "team": "ٹیم",
    "pakistan": "پاکستان", "india": "انڈیا", "khan": "خان",
    "imran": "عمران", "economy": "معیشت", "speech": "تقریر",
    "babar": "بابر", "azam": "اعظم", "ny": "نے",
    "kiya": "کیا", "lekin": "لیکن", "haar": "ہار",
    "geya": "گیا", "score": "اسکور", "century": "سنچری",
    "aur": "اور", "ka": "کا", "ki": "کی",
    "ke": "کے", "pm": "وزیراعظم", "bayan": "بیان",
    "game": "گیم", "goal": "گول", "win": "جیت",
    "bank": "بینک", "dollar": "ڈالر", "market": "مارکیٹ",
}

print(f"✅ Base dictionary loaded!")
print(f"Total words: {len(roman_to_urdu_base)}")
print(f"\nSample entries:")
for k,v in list(roman_to_urdu_base.items())[:5]:
    print(f"  {k} → {v}")
# Out:
#   Cell In[2], line 12
#     "bank": "بینک", "
#                     ^
# SyntaxError: unterminated string literal (detected at line 12)
